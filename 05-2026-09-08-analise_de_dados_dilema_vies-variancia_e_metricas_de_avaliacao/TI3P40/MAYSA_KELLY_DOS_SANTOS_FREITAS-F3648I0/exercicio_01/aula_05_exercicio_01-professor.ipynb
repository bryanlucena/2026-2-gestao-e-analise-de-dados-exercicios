# %% [markdown]
# ## Importar Bibliotecas

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Carregar Dados de entrada (X) e Saída (Y) - DADOS DE TREINO

# %%
X_train = np.array([
    [2],
    [3],
    [4],
    [5],
    [6],
    [8],
    [10]
])

y_train = np.array([
    18,
    21,
    25,
    28,
    32,
    38,
    45
])

# %% [markdown]
# ## Carregar Dados de entrada (X) e Saída (Y) - Dados de Teste

# %%
X_test = np.array([
    [3.5],
    [7],
    [9]
])

y_test = np.array([
    23,
    35,
    42
])

# %% [markdown]
# ## Escolher Tipo de Modelo

# %%
modelo = LinearRegression()

# %% [markdown]
# ## Fazer o Treino dos dados de treino (Gerar seu modelo)

# %%
modelo.fit(X_train, y_train)

w = modelo.coef_[0]
b = modelo.intercept_

# %% [markdown]
# ## Escrever os valores dos parâmetros "w" e "b" na tela

# %%
print("w =", w)
print("b =", b)

# %% [markdown]
# ## Executar o TESTE (predizer o valor)

# %%
y_pred = modelo.predict(X_test)

print("Previsões:", y_pred)

# %% [markdown]
# ## Calcular o erro , o seja, a qualidade do seu modelo para prever este fenômeno

# %%
mse = mean_squared_error(y_test, y_pred)

print("MSE teste =", mse)

# %% [markdown]
# ## Finalmente calcular o tempo estimado da entrega

# %%
nova_distancia = np.array([[7.5]])
tempo_estimado = modelo.predict(nova_distancia)
print("Tempo estimado:", tempo_estimado[0])
# Out:
# Tempo estimado: 36.57335329341318

# %%
# Out:
# w = 3.3802395209580833
# b = 11.22155688622755
# Previsões: [23.05239521 34.88323353 41.64371257]
# MSE teste = 0.04777346504595675
# Tempo estimado: 36.57335329341318
